// %% [markdown]
// ********************
// Last names: Valenzuela
// Language: Kotlin
// Paradigm(s): Object Oriented
// ********************

// %% [markdown]
// # Corpus Analysis Using Kotlin
// -------------

// %% [markdown]
// ### Import Libraries

// %%
import java.awt.Color
import java.awt.Font
import java.awt.Graphics2D
import java.awt.Rectangle
import java.awt.image.BufferedImage
import java.io.File
import javax.imageio.ImageIO
import kotlin.random.Random
import java.time.LocalDate
import java.time.format.DateTimeFormatter

// %% [markdown]
// ### Function to load dates from CSV file

// %%
fun loadDatesFromCsv(filePath: String): List<String> {
    val file = File(filePath)
    val dates = mutableListOf<String>()

    file.forEachLine { line ->
        if (!line.startsWith("tweet_id,")) {
            val columns = line.split(",(?=([^\"]*\"[^\"]*\")*[^\"]*$)".toRegex())
            if (columns.size > 2) {
                dates.add(columns[2].trim()) // Extract date_created column
            }
        }
    }
    return dates
}

// %% [markdown]
// ### Function to load text from the CSV file

// %%
fun loadTextFromCsv(filePath: String): List<String> {
    val file = File(filePath)
    val corpus = mutableListOf<String>()

    file.forEachLine { line ->
        if (!line.startsWith("tweet_id,")) {
            val columns = line.split(",(?=([^\"]*\"[^\"]*\")*[^\"]*$)".toRegex())
            if (columns.size > 3) {
                corpus.add(columns[3].trim().lowercase()) // Extract text column
            }
        }
    }
    return corpus
}

// %% [markdown]
// ### Function to count the total number of words

// %%
fun wordCount(corpus: List<String>): Int {
    return corpus.sumOf { it.split("\\s+".toRegex()).size }
}

// %% [markdown]
// ### Function to count the unique words (vocabulary size)

// %%
fun vocabularySize(corpus: List<String>): Int {
    return corpus.flatMap { it.split("\\s+".toRegex()) }
        .filter { it.isNotBlank() }
        .distinct()
        .size
}

// %% [markdown]
// ### Function to count how many times a word appears in the texts

// %%
fun wordFrequency(corpus: List<String>): Map<String, Int> {
    return corpus.flatMap { it.split("\\s+".toRegex()) }
        .filter { it.isNotBlank() } 
        .groupingBy { it }
        .eachCount()
        .toList()
        .sortedByDescending { (_, count) -> count }
        .toMap()
}

// %% [markdown]
// ### Function to count how many times a character was used in the texts

// %%
fun characterFrequency(corpus: List<String>): Map<Char, Int> {
    return corpus.flatMap { it.toList() }
        .groupingBy { it }
        .eachCount()
        .toList()
        .sortedByDescending { (_, count) -> count }
        .toMap()
}

// %% [markdown]
// ### Function to get the frequency of stop words in the texts

// %%
fun identifyStopWords(wordFrequencies: Map<String, Int>, stopWords: Set<String>): Map<String, Int> {
    return wordFrequencies.filter { (word, _) -> stopWords.contains(word) }
}

// %% [markdown]
// ### Function that displays the top 20 most used words

// %%
fun showTopFrequentWords(wordFrequencies: Map<String, Int>, topN: Int = 20) {
    println("Top $topN Frequent Words:")
    wordFrequencies.entries.take(topN).forEach { (word, freq) ->
        println("$word: $freq")
    }
}

// %% [markdown]
// ### Function that displays the top 10 most used characters

// %%
fun showTopFrequentCharacters(charFrequencies: Map<Char, Int>, topN: Int = 10) {
    println("Top $topN Frequent Characters:")
    charFrequencies.entries.take(topN).forEach { (char, freq) ->
        println("$char: $freq")
    }
}

// %% [markdown]
// ### Function that generates a word cloud using java.awts elements and outputs it as a png file

// %%
fun generateWordCloud(wordFrequencies: Map<String, Int>, outputFilePath: String) {
    val width = 800
    val height = 600

    val image = BufferedImage(width, height, BufferedImage.TYPE_INT_RGB)
    val graphics = image.createGraphics()

    graphics.color = Color.WHITE
    graphics.fillRect(0, 0, width, height)

    val placedWords = mutableListOf<Rectangle>()

    val sortedWords = wordFrequencies.entries.sortedByDescending { it.value }.take(20)
    val centerX = width / 2
    val centerY = height / 2

    sortedWords.forEachIndexed { index, (word, frequency) ->
        val fontSize = (10 + frequency * 5).coerceAtMost(60) // Clamp font size to a maximum
        graphics.font = Font("Arial", Font.BOLD, fontSize)

        val wordWidth = graphics.fontMetrics.stringWidth(word)
        val wordHeight = graphics.fontMetrics.height

        var x: Int
        var y: Int
        var attempts = 0

        while (true) {
            if (index == 0 && attempts == 0) {
                // Place the largest word at the center
                x = centerX - wordWidth / 2
                y = centerY + wordHeight / 2
                val rect = Rectangle(x, y - wordHeight, wordWidth, wordHeight)
                placedWords.add(rect)
                break
            } else {
                // Random placement
                x = (0 until (width - wordWidth)).random()
                y = (wordHeight until (height - wordHeight)).random()

                val newWordRect = Rectangle(x, y - wordHeight, wordWidth, wordHeight)
                if (placedWords.none { it.intersects(newWordRect) }) {
                    placedWords.add(newWordRect)
                    break
                }

                attempts++
                if (attempts > 100) {
                    println("Failed to place word: $word after 100 attempts.")
                    break
                }
            }
        }

        // Set random color
        graphics.color = Color(
            (50..255).random(),
            (50..255).random(),
            (50..255).random()
        )

        // Draw the word
        graphics.drawString(word, x, y)
    }

    ImageIO.write(image, "png", File(outputFilePath))
    graphics.dispose()

    println("Word cloud saved to $outputFilePath")
}

// %%
fun createHistogram(data: Map<String, Int>, outputFilePath: String) {
    val width = 800
    val height = 600
    val barWidth = 50
    val padding = 50

    // Create a buffered image
    val image = BufferedImage(width, height, BufferedImage.TYPE_INT_RGB)
    val graphics = image.createGraphics()

    // Draw background
    graphics.color = Color.WHITE
    graphics.fillRect(0, 0, width, height)

    // Draw axes
    graphics.color = Color.BLACK
    graphics.drawLine(padding, height - padding, width - padding, height - padding) // X-axis
    graphics.drawLine(padding, padding, padding, height - padding) // Y-axis

    // Find max value for scaling
    val maxValue = data.values.maxOrNull() ?: 1

    // Draw bars
    val keys = data.keys.toList()
    val values = data.values.toList()
    for (i in keys.indices) {
        val x = padding + i * (barWidth + 10)
        val barHeight = ((values[i].toDouble() / maxValue) * (height - 2 * padding)).toInt()
        val y = height - padding - barHeight

        // Draw bar
        graphics.color = Color((50..255).random(), (50..255).random(), (50..255).random())
        graphics.fillRect(x, y, barWidth, barHeight)

        // Draw labels
        graphics.color = Color.BLACK
        graphics.drawString(keys[i], x + barWidth / 4, height - padding + 15)
        graphics.drawString(values[i].toString(), x + barWidth / 4, y - 5)
    }

    // Save image to file
    ImageIO.write(image, "png", File(outputFilePath))
    graphics.dispose()

    println("Histogram saved to $outputFilePath")
}

// %%
fun getTweetsPerMonth(filePath: String): Map<String, Int> {
    val dateFormatter = DateTimeFormatter.ofPattern("yyyy-MM-dd HH:mm:ss")
    val tweetsPerMonth = mutableMapOf<String, Int>()

    File(filePath).forEachLine { line ->
        if (!line.startsWith("tweet_id,")) { // Skip header
            val columns = line.split(",(?=([^\"]*\"[^\"]*\")*[^\"]*$)".toRegex())
            if (columns.size > 2) {
                val dateStr = columns[2].trim()
                try {
                    // Parse the full date and time string
                    val dateTime = LocalDate.parse(dateStr, dateFormatter)

                    // Extract year and month
                    val month = "${dateTime.year}-${dateTime.monthValue.toString().padStart(2, '0')}" // Format: YYYY-MM
                    tweetsPerMonth[month] = tweetsPerMonth.getOrDefault(month, 0) + 1
                } catch (e: Exception) {
                    println("Error parsing date: $dateStr")
                }
            }
        }
    }
    return tweetsPerMonth
}

// %% [markdown]
// ### Load CSV

// %%
val csvFilePath = "fake_tweets.csv"

val corpus = loadTextFromCsv(csvFilePath)
if (corpus.isEmpty()) {
    println("No data loaded from CSV. Exiting program.")
}

// %% [markdown]
// ### Load dates from CSV

// %%
val dates = loadDatesFromCsv(csvFilePath)
if (dates.isEmpty() || corpus.isEmpty()) {
    println("No data loaded from CSV. Exiting program.")
}
println("Dates and text data loaded successfully.")
println("Total dates: ${dates.size}, Total text entries: ${corpus.size}")
// Out:
// Dates and text data loaded successfully.
// Total dates: 100, Total text entries: 100

// %% [markdown]
// ### Show descriptive statistics

// %%
val wordFrequencies = wordFrequency(corpus)

val wordsSortedByFrequency = wordFrequencies.entries
    .sortedByDescending { it.value } 
    .associate { it.toPair() } 

val charFrequencies = characterFrequency(corpus)

val charsSortedByFrequency = charFrequencies.entries
.sortedByDescending { it.value } 
.associate { it.toPair() }

val totalWordCount = wordCount(corpus)
val vocabSize = vocabularySize(corpus)

println("\nDescriptive Statistics:")
println("Total Word Count: $totalWordCount")
println("Vocabulary Size: $vocabSize")
println("\nWord Frequency:")
wordsSortedByFrequency.forEach { (word, count) ->
    println("$word: $count")
}
// Out:
// Descriptive Statistics:
// Total Word Count: 720
// Vocabulary Size: 530
//
// Word Frequency:
// #travel: 24
// #news: 20
// #food: 19
// #trending: 14
// #funny: 11
// 😱: 7
// citizen: 3
// single: 3
// unit: 3
// itself: 3
// serve: 3
// of: 3
// forget: 3
// 😭: 3
// soldier: 3
// throughout: 3
// bill: 3
// deep: 3
// measure.: 3
// instead: 3
// poor: 3
// 🤯: 3
// church: 3
// deal: 3
// budget: 3
// through: 3
// political: 2
// show: 2
// pretty: 2
// race.: 2
// assume: 2
// book: 2
// but: 2
// minute: 2
// establish: 2
// ok: 2
// allow: 2
// 👍: 2
// southern: 2
// one: 2
// or: 2
// people: 2
// ago: 2
// newspaper: 2
// them: 2
// front: 2
// yeah: 2
// power: 2
// agree: 2
// quickly: 2
// activity: 2
// purpose: 2
// my: 2
// heavy: 2
// news: 2
// side: 2
// well.: 2
// food: 2
// never: 2
// remain: 2
// media.: 2
// left: 2
// much: 2
// 😍: 2
// view: 2
// teacher: 2
// south: 2
// continue: 2
// increase: 2
// happen: 2
// wall: 2
// education: 2
// several: 2
// future.: 2
// ❤️: 2
// recent: 2
// to: 2
// what: 2
// reveal: 2
// center: 2
// 🔥: 2
// other: 2
// production: 2
// half: 2
// us: 2
// themselves: 2
// cost: 2
// common: 1
// any.: 1
// camera: 1
// ready: 1
// @user2471465: 1
// 😂: 1
// opportunity: 1
// family: 1
// style: 1
// manage: 1
// personal.: 1
// gun: 1
// throw: 1
// space.: 1
// international: 1
// Character Frequency:
//  : 620
// e: 534
// r: 340
// t: 276
// n: 257
// s: 251
// a: 247
// o: 241
// i: 220
// u: 197
// l: 184
// c: 135
// d: 133
// h: 112
// .: 100
// f: 89
// #: 88
// g: 83
// p: 82
// w: 73
// y: 73
// @: 71
// m: 68
// 3: 60
// 5: 59
// v: 59
// 7: 58
// 9: 56
// 2: 53
// 8: 48
// 6: 45
// 1: 44
// b: 40
// 4: 37
// 0: 37
// k: 20
// ?: 17
// ?: 7
// x: 7
// z: 6
// q: 5
// ?: 3
// ?: 3
// ?: 3
// ?: 2
// j: 2
// ?: 2
// ❤: 2
// ️: 2
// ?: 2
// ?: 1

// %%
println("\nFrequency Analysis:")
showTopFrequentWords(wordsSortedByFrequency, 20)
// Out:
// Frequency Analysis:
// Top 20 Frequent Words:
// #travel: 24
// #news: 20
// #food: 19
// #trending: 14
// #funny: 11
// 😱: 7
// citizen: 3
// single: 3
// unit: 3
// itself: 3
// serve: 3
// of: 3
// forget: 3
// 😭: 3
// soldier: 3
// throughout: 3
// bill: 3
// deep: 3
// measure.: 3
// instead: 3

// %%
val stopWords = setOf("although", "happen", "new", "none", "form", "something", "where", "try", "out", "medical")

val identifiedStopWords = identifyStopWords(wordFrequencies, stopWords)

println("\nStop Word Identification:")
identifiedStopWords.entries.take(10).forEach { (word, count) ->
    println("$word: $count")
}
// Out:
// Stop Word Identification:
// happen: 2
// try: 1
// where: 1
// new: 1
// although: 1
// form: 1
// none: 1
// medical: 1

// %% [markdown]
// ### Generate word cloud

// %%
val outputFilePath = "wordcloud_custom.png"
    generateWordCloud(wordFrequencies, outputFilePath)
// Out:
// Word cloud saved to wordcloud_custom.png

// %%
val tweetsPerMonth = getTweetsPerMonth(csvFilePath)
createHistogram(tweetsPerMonth, "posts_histogram.png")
// Out:
// Histogram saved to posts_histogram.png

// %% [markdown]
// ## Data Visualization

// %%
// Fetch latest versions of libraries descriptors
%useLatestDescriptors
// Add kandy library
%use kandy
// Add dataframe
%use dataframe
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %% [markdown]
// ### Bar graph for top 20 most frequent words

// %%
// Prepare data for top 20 words in the format Kandy expects
val top20WordsData = wordsSortedByFrequency.entries
    .take(20)
    .map { (word, count) -> 
        mapOf(
            "word" to word,
            "frequency" to count
        )
    }

val plotData = mapOf(
    "word" to top20WordsData.map { it["word"] },
    "frequency" to top20WordsData.map { it["frequency"] }
)

plot(plotData) {
    x("word")
    y("frequency") {
        scale = continuous()
    }
    
    bars {
        fillColor = Color.hex("#6e5596")
        borderLine.width = 0.0
    }
    
    layout {
        title = "Top 20 Most Frequent Words"
        size = 800 to 400  
 
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='800' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;8lgbBj&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Top 20 Most Frequent Words&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;word&quot;:[&quot;#travel&quot;,&quot;#news&quot;,&quot;#food&quot;,&quot;#trending&quot;,&quot;#funny&quot;,&quot;😱&quot;,&quot;citizen&quot;,&quot;single&quot;,&quot;unit&quot;,&quot;itself&quot;,&quot;serve&quot;,&quot;of&quot;,&quot;forget&quot;,&quot;😭&quot;,&quot;soldier&quot;,&quot;throughout&quot;,&quot;bill&quot;,&quot;deep&quot;,&quot;measure.&quot;,&quot;instead&quot;],
// &quot;frequency&quot;:[24.0,20.0,19.0,14.0,11.0,7.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0,3.0]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:800.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;word&quot;,
// &quot;y&quot;:&quot;frequency&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:0.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;#6e5596&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;8lgbBj&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=2f3bfd36-1313-49d8-9255-ff9f3a06c710 width="100%" height="100%" style="max-width: 800.0px; max-height: 400.0px;" viewBox="0 0 800.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #paeIxFn .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #djnZOCO .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #djnZOCO .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #paeIxFn .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #djnZOCO .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #djnZOCO .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #djnZOCO .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="paeIxFn">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L800.0 400.0 L800.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="23.759862704822236" y1="0.0" x2="23.759862704822236" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="60.31349763531799" y1="0.0" x2="60.31349763531799" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="96.86713256581373" y1="0.0" x2="96.86713256581373" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="133.42076749630948" y1="0.0" x2="133.42076749630948" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="169.97440242680523" y1="0.0" x2="169.97440242680523" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="206.52803735730097" y1="0.0" x2="206.52803735730097" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="243.08167228779672" y1="0.0" x2="243.08167228779672" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="279.63530721829244" y1="0.0" x2="279.63530721829244" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="316.1889421487882" y1="0.0" x2="316.1889421487882" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="352.74257707928393" y1="0.0" x2="352.74257707928393" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="389.2962120097797" y1="0.0" x2="389.2962120097797" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="425.8498469402755" y1="0.0" x2="425.8498469402755" y2="262.9152908836876" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="462.4034818707712" y1="0.0" x2="462.4034818707712" y2="262.9152908836876" stroke="r

// %% [markdown]
// ### Histogram showing number of posts per month

// %%
val monthlyData = dates.groupBy { date ->
    date.substring(0, 7) // Gets YYYY-MM format
}.mapValues { it.value.size }

val monthPlotData = mapOf(
    "month" to monthlyData.keys.toList(),
    "count" to monthlyData.values.toList()
)

plot(monthPlotData) {
    x("month")
    y("count") {
        scale = continuous()
    }
    
    bars {
        fillColor = Color.hex("#4CAF50")
        borderLine.width = 0.0
    }
    
    layout {
        title = "Posts per Month"
        size = 700 to 400
    
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='700' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;204vUa&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Posts per Month&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;month&quot;:[&quot;2024-03&quot;,&quot;2024-05&quot;,&quot;2023-08&quot;,&quot;2023-09&quot;,&quot;2023-03&quot;,&quot;2024-06&quot;,&quot;2023-10&quot;,&quot;2023-11&quot;,&quot;2024-02&quot;,&quot;2023-02&quot;,&quot;2023-04&quot;,&quot;2023-06&quot;,&quot;2023-12&quot;,&quot;2024-10&quot;,&quot;2023-07&quot;,&quot;2024-07&quot;,&quot;2023-05&quot;,&quot;2024-09&quot;,&quot;2024-01&quot;,&quot;2023-01&quot;,&quot;2024-08&quot;],
// &quot;count&quot;:[6.0,5.0,8.0,10.0,4.0,4.0,7.0,3.0,6.0,5.0,5.0,7.0,4.0,4.0,3.0,5.0,3.0,3.0,3.0,3.0,2.0]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;month&quot;,
// &quot;y&quot;:&quot;count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:0.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;#4CAF50&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;204vUa&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=85353c12-f074-4dcd-ac96-519a009b9037 width="100%" height="100%" style="max-width: 700.0px; max-height: 400.0px;" viewBox="0 0 700.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #ps3tMkj .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRcNd6y .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRcNd6y .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ps3tMkj .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRcNd6y .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dRcNd6y .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dRcNd6y .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="ps3tMkj">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L700.0 400.0 L700.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="19.592733000370487" y1="0.0" x2="19.592733000370487" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="49.73539915478662" y1="0.0" x2="49.73539915478662" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="79.87806530920275" y1="0.0" x2="79.87806530920275" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="110.02073146361889" y1="0.0" x2="110.02073146361889" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="140.16339761803502" y1="0.0" x2="140.16339761803502" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="170.30606377245115" y1="0.0" x2="170.30606377245115" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="200.4487299268673" y1="0.0" x2="200.4487299268673" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="230.59139608128342" y1="0.0" x2="230.59139608128342" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="260.7340622356995" y1="0.0" x2="260.7340622356995" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="290.87672839011566" y1="0.0" x2="290.87672839011566" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="321.0193945445318" y1="0.0" x2="321.0193945445318" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="351.1620606989479" y1="0.0" x2="351.1620606989479" y2="278.13576181172255" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="381.30472685336406" y1="0.0" x2="381.304

// %% [markdown]
// ### Pie chart showing the distribution of symbols in the corpus

// %%
val symbolData = charsSortedByFrequency.entries
    .filter { !it.key.isLetterOrDigit() && !it.key.isWhitespace() }
    .take(6)  // Taking top 20 symbols to keep visualization manageable
    .toList()
    
val symbolDataFrame = dataFrameOf(
    "symbol" to symbolData.map { it.key },
    "frequency" to symbolData.map { it.value }
)

// Generate the pie chart
symbolDataFrame.plot {
    pie {
        slice("frequency") 
        fillColor("symbol") 
    }
    layout {
        title = "Symbol Distribution in Corpus"
        size = 700 to 400
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='700' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;jb0cIV&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Symbol Distribution in Corpus&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;symbol&quot;:[&quot;.&quot;,&quot;#&quot;,&quot;@&quot;,&quot;?&quot;,&quot;?&quot;,&quot;?&quot;],
// &quot;frequency&quot;:[100.0,88.0,71.0,17.0,7.0,3.0]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:700.0,
// &quot;height&quot;:400.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;frequency&quot;,
// &quot;fill&quot;:&quot;symbol&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;jb0cIV&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=123f0ea6-caa4-45d3-86d8-4fb995b3354e width="100%" height="100%" style="max-width: 700.0px; max-height: 400.0px;" viewBox="0 0 700.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pqUXX0I .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dQ5dLf5 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dQ5dLf5 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pqUXX0I .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dQ5dLf5 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dQ5dLf5 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dQ5dLf5 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pqUXX0I">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L700.0 400.0 L700.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="55.318308762218464" y1="0.0" x2="55.318308762218464" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="165.95492628665545" y1="0.0" x2="165.95492628665545" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="276.59154381109244" y1="0.0" x2="276.59154381109244" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="387.2281613355294" y1="0.0" x2="387.2281613355294" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="497.8647788599664" y1="0.0" x2="497.8647788599664" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="288.9" x2="553.1830876221849" y2="288.9" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="224.7" x2="553.1830876221849" y2="224.7" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="160.5" x2="553.1830876221849" y2="160.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="96.3" x2="553.1830876221849" y2="96.3" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="32.099999999999994" x2="553.1830876221849" y2="32.099999999999994" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cGGedKp)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (553.1830876221849, 321.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <path d="M276.59154381109244 160.5 L236.07622596294425 189.8003245658393 A50.0 50.0 0.0 0 1 276.59154381109244 110.5 L276.59154381109244 160.5 A0.0 0.0 0.0 0 0 276.59154381109244 160.5 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M276.59154381109244 160.5 L276.59154381109244 110.5 A50.0 50.0 0.0 0 1 323.3423559453632 178.2302443521268 L276.59154381109244 160.5 A0.0 0.0 0.0 0 0 276.59154381109244 160.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M276.59154381109244 160.5 L323.3423559453632 178.2302443521268 A50.0 50.0 0.0
